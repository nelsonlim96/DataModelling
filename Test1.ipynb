# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

import statsmodels.api as sm
import statsmodels.formula.api as smf

from DataModelling import DataModelling

# %%
path = 'train.csv'

# %%
a = DataModelling(path, target='Fare')
a.run()
# Out:
# 1. The columns in this dataframe are:
# PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked
#
# 2. There are 891 rows in this dataframe
#
# 3. The number of missing data in this dataframe are:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Fare   R-squared:                       0.432
# Model:                            OLS   Adj. R-squared:                  0.427
# Method:                 Least Squares   F-statistic:                     83.70
# Date:                Fri, 27 Mar 2020   Prob (F-statistic):          8.77e-103
# Time:                        15:38:15   Log-Likelihood:                -4481.8
# No. Observations:                 889   AIC:                             8982.
# Df Residuals:                     880   BIC:                             9025.
# Df Model:                           8
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        85.8047      4.913     17.465      0.000      76.162      95.447
# Pclass[T.2]     -58.7314      3.942    -14.899      0.000     -66.468     -50.994
# Pclass[T.3]     -66.5124      3.423    -19.433      0.000     -73.230     -59.795
# Sex[T.male]      -3.6041      3.274     -1.101      0.271     -10.030       2.822
# Embarked[T.Q]   -12.0024      5.456     -2.200      0.028     -22.711      -1.294
# Embarked[T.S]   -13.7808      3.436     -4.011      0.000     -20.524      -7.038
# Survived          4.2258      3.285      1.286      0.199      -2.222      10.674
# SibSp             5.9309      1.269      4.675      0.000       3.441       8.421
# Parch             9.9876      1.773      5.633      0.000       6.508      13.467
# ==============================================================================
# Omnibus:                     1043.489   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           119841.568
# Skew:                           5.736   Prob(JB):                         0.00
# Kurtosis:                      58.711   Cond. No.                         9.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
